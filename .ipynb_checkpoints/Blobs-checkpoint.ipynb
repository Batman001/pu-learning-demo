# %%
import pandas as pd                    # for data handling
import numpy as np                     # for random selections, mainly
import matplotlib.pyplot as plt        # for plotting
# %matplotlib inline                  
plt.rcParams['figure.figsize'] = 7,7   # graph dimensions
plt.rcParams['font.size'] = 14         # graph font size
import matplotlib
matplotlib.rcParams['font.sans-serif']=['SimHei']   # 用黑体显示中文
matplotlib.rcParams['axes.unicode_minus']=False     # 正常显示负号

# %% [markdown]
# ### create datasets of blobs

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(
    n_samples = 6000, 
    centers = [[1,5], [5,1], [0,0], [6,6]]
)
y = (y>1).astype(int)
X = pd.DataFrame(X, columns=['feature1', 'feature2'])
y = pd.Series(y)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Check the contents of the set
print('%d data points and %d features' % (X.shape))
print('%d positive out of %d total' % (sum(y), len(y)))
# Out:
# 6000 data points and 2 features
# 3000 positive out of 6000 total

# %% [markdown]
# ## plot the original data set

# %%
plt.scatter(
    X[y==0].feature1, X[y==0].feature2,
    c='k', marker='.', linewidths=1, s=10, alpha=0.5, 
    label='Unlabeled'
)

plt.scatter(
    X[y==1].feature1, X[y==1].feature2,
    c='b', marker='o', linewidth=0, s=50, alpha=0.5,
    label='Positive'
)
plt.legend()
plt.title('Original Data set (as seen by the classifiers')
plt.show()

# %% [markdown]
# ### 对标记为1的样本取消其样本label 取消数量为hidden_size=2700

# %%
y_orig = y.copy()

hidden_size = 2700
y.loc[
    np.random.choice(
        y[y==1].index,
        replace=False,
        size=hidden_size
    )
] = 0

# %%
# Check the new contents of the set
print('%d positive out of %d total' % (sum(y), len(y)))
# Out:
# 300 positive out of 6000 total

# %%
# plot the data set, as model can see it
plt.scatter(
    X[y==0].feature1, X[y==0].feature2,
    c='k', marker='.', linewidths=1, s=10, alpha=0.5, 
    label='Unlabeled'
)

plt.scatter(
    X[y==1].feature1, X[y==1].feature2,
    c='b', marker='o', linewidth=0, s=50, alpha=0.5,
    label='Positive'
)
plt.legend()
plt.title('Data set (as seen by the classifiers')
plt.show()

# %% [markdown]
# ## PU-Learning
# ### 1.1 standard classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(
    n_estimators=100, 
    n_jobs=-1
)
forest.fit(X, y)

results = pd.DataFrame(
{
    'truth': y_orig,
    'label': y,
    'output_std': forest.predict_proba(X)[:, 1]
}, columns=['truth', 'label', 'output_std']
)

# %% [markdown]
# ### 1.2  conclusion of standard classifier
# - 展示lable==0的全部数据，查看经过standard classifier发现的positive的样本

# %%
plt.rcParams['figure.figsize'] = 9, 7
plt.scatter(
    X[y==0].feature1, X[y==0].feature2,
    c = results[y==0].output_std, linewidth=0, s=50, alpha=0.5, cmap='jet_r'
)
plt.colorbar(label='Scores given to unlabeled points')
plt.title('Standard Classifier')
plt.show()

# %% [markdown]
# ## 2.1 Bagging

# %%
num_oob = pd.DataFrame(np.zeros(shape=y.shape), index=y.index)

# %%
from sklearn.tree import DecisionTreeClassifier
n_estimators = 1000
estimator = DecisionTreeClassifier()

iP = y[y>0].index
iU = y[y<=0].index

# 对于每次的数据迭代，记录数据被OOB的次数
num_oob = pd.DataFrame(np.zeros(shape=y.shape), index=y.index)

# 记录每一轮 OOB data的score
sum_oob = pd.DataFrame(np.zeros(shape=y.shape), index=y.index)

for _ in range(n_estimators):
    
    # Bootstrap 抽取数据 
    iB = np.random.choice(iU, replace=True, size=len(iP))
    
    i_oob = list(set(iU) - set(iB))
    
    Xb= X[y>0].append(X.loc[iB])
    yb = y[y>0].append(y.loc[iB])
    
    estimator.fit(Xb, yb)
    
    sum_oob.loc[i_oob, 0] += estimator.predict_proba(X.loc[i_oob])[:, 1]
    num_oob.loc[i_oob, 0] += 1

results['output_bag'] = sum_oob / num_oob

# %% [markdown]
# ## 2.2 conclusion
# - PU-Learning bagging的数据 可视化展示label==0的数据

# %%
plt.scatter(
    X[y==0].feature1, X[y==0].feature2,
    c=results[y==0].output_bag, linewidth=0, s=50, alpha=0.5, cmap='jet_r'
)
plt.colorbar(label='Score given to unlabeled points')
plt.title('PU Bagging')
plt.show()

# %% [markdown]
# ## 3.1 Using `BaggingClassifierPU`

# %%
from baggingPU import BaggingClassifierPU
bc = BaggingClassifierPU(
    DecisionTreeClassifier(),
    n_estimators = 1000,
    max_samples = sum(y),
    n_jobs = -1
)
bc.fit(X, y)
results['output_skb'] = bc.oob_decision_function_[:, 1]
# Out:
# D:\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# D:\anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# D:\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Visualize the approach's result
plt.scatter(
    X[y==0].feature1, X[y==0].feature2,
    c=results[y==0].output_skb, linewidth=0, s=50, alpha=0.5, cmap='jet_r'
)
plt.colorbar(label='Scores given to unlabeled points')
plt.title(r'Using ${\tt BaggingClassifierPU}$')
plt.show()

# %% [markdown]
# ## 4. Using `Two-Step`
# ### 4.1 Step1 + Step2

# %%
# 对label进行调整 1 表示为positive；-1 表示为未标注数据；0 表示为实锤negative
ys = 2 * y -1

# 根据普遍意义的随机森林预测样本数据
pred = forest.predict_proba(X)[:,1]

# 根据预测结果 判断 positive 数据的概率范围
range_P = [min(pred * (ys>0)), max(pred * (ys>0))]


# STEP 1
# 如果未标注数据 得到score超过全部已知的positive样本数据的score值，则label为postive
# 或者score低于全部已知的positive的score值 ，则label为negative

# 新的positive样本
iP_new = ys[(ys<0) & (pred >= range_P[1])].index
# 新的negative样本
iN_new = ys[(ys<0) & (pred <= range_P[0])].index

# 实锤unlabeled样本数据的标签
ys.loc[iP_new] = 1
ys.loc[iN_new] = 0

# STEP1通过散点图查看标注的效果
plt.rcParams['figure.figsize'] = 7,7
cdict = {-1: 'gray', 0: 'darkred', 1: 'blue'}

plt.scatter(
    X.feature1, X.feature2,
    c = [cdict[k] for k in ys],
    linewidths=0, s=20, alpha=0.5
)

plt.title('Label after STEP 1')
plt.show()


# Classifier to be used for step 2
rf2 = RandomForestClassifier(n_estimators = 1000, n_jobs = -1)

# Limit to 10 iterations (this is arbitrary, but 
# otherwise this approach can take a very long time)
# 随机设置超参数迭代次数为10次
for i in range(10):
    # If step 1 didn't find new labels, we're done
    if len(iP_new) + len(iN_new) == 0 and i > 0:
        break
    
    print('Step 1 labeled %d new positives and %d new negatives.' %(len(iP_new), len(iN_new)))
    print('正在执行Step2，当前迭代次数为%d次' %(i+1), end=' ')
    
    # STEP 2
    # Retrain on new labels and get new scores
    rf2.fit(X, ys)
    pred = rf2.predict_proba(X)[:,-1]
    
    # Find the range of scores given to positive data points
    range_P = [min(pred * (ys > 0)), max(pred * (ys > 0))]
    
    # Repeat step 1
    iP_new = ys[(ys < 0) & (pred >= range_P[1])].index
    iN_new = ys[(ys < 0) & (pred <= range_P[0])].index
    ys.loc[iP_new] = 1
    ys.loc[iN_new] = 0
    
    
# Lastly, get the scores assigned by this approach    
results['output_stp'] = pred
# Out:
# Step 1 labeled 0 new positives and 3606 new negatives.
# 正在执行Step2，当前迭代次数为1次 Step 1 labeled 0 new positives and 87 new negatives.
# 正在执行Step2，当前迭代次数为2次 Step 1 labeled 0 new positives and 36 new negatives.
# 正在执行Step2，当前迭代次数为3次 Step 1 labeled 0 new positives and 16 new negatives.
# 正在执行Step2，当前迭代次数为4次 Step 1 labeled 0 new positives and 12 new negatives.
# 正在执行Step2，当前迭代次数为5次 Step 1 labeled 0 new positives and 5 new negatives.
# 正在执行Step2，当前迭代次数为6次 Step 1 labeled 0 new positives and 7 new negatives.
# 正在执行Step2，当前迭代次数为7次 Step 1 labeled 0 new positives and 8 new negatives.
# 正在执行Step2，当前迭代次数为8次 Step 1 labeled 0 new positives and 6 new negatives.
# 正在执行Step2，当前迭代次数为9次 Step 1 labeled 0 new positives and 4 new negatives.
# 正在执行Step2，当前迭代次数为10次

# %% [markdown]
# ### 4.2 对Two-Step方法的效果可视化展示

# %%
# Visualize this approach's final results
plt.rcParams['figure.figsize']=9,7
plt.scatter(
    X[y==0].feature1, X[y==0].feature2,
    c=results[y==0].output_stp, linewidths=0, s=50, alpha=0.5, cmap='jet_r'
)
plt.colorbar(label='Scored given to unlabeled points')
plt.title('Two-Step method PU Learning')
plt.show()

# %% [markdown]
# ## 5. 方法比较

# %%
# 对于每一个数据，计算3种方法的平均值
results['output_all'] = results[['output_std', 'output_bag', 'output_stp']].mean(axis=1)

# %% [markdown]
# #### 5.1 可视化三种不同方法的平均效果

# %%
plt.rcParams['figure.figsize'] = 9, 7
plt.scatter(
    X[y==0].feature1, X[y==0].feature2, c=results[y==0].output_all, linewidths=0, s=50, alpha=0.5
)
plt.colorbar(label='Scores given to unlabeled points')
plt.title('Averaging')
plt.show()

# %% [markdown]
# #### 5.2 对于三种不同的PU-Learning的表现可视化展示
# - 成功识别隐藏positive样本的数量

# %%
results[results.label==0].sort_values('output_std', ascending=False).head(t).truth
# Out:
#       truth  label  output_std  output_bag  output_skb  output_stp  output_all
# 91        1      0        0.30    0.955743    0.951933       0.201    0.485581
# 5685      1      0        0.28    0.941983    0.937041       0.237    0.486328
# 590       1      0        0.27    0.980042    0.974843       0.205    0.485014
# 4105      1      0        0.26    0.986287    0.984127       0.292    0.512762
# 2115      1      0        0.26    0.957380    0.964211       0.228    0.481793
# ...     ...    ...         ...         ...         ...         ...         ...
# 2407      0      0        0.00    0.000000    0.000000       0.000    0.000000
# 2410      0      0        0.00    0.013627    0.005219       0.000    0.004542
# 2411      0      0        0.00    0.000000    0.000000       0.000    0.000000
# 2413      0      0        0.00    0.001055    0.002068       0.000    0.000352
# 5999      0      0        0.00    0.000000    0.000000       0.001    0.000333
#
# [5700 rows x 7 columns]

# %%
# 将全部hidden_size 按照步长为100设置不同的数量级
ts = range(100, hidden_size, 100)
y_std, y_bag, y_skb, y_stp, y_all = [], [], [], [], []

for t in ts:
    # 针对不同的PU-Learning的方法添加  
    # 对未标注数据的识别的positive分数最高的TOP(100,200,300,....3000) 真正positive样本的平均值
    
    # 方法一: standard classifier
    y_std.append(
        results[results.label==0].sort_values(
            'output_std', ascending=False
        ).head(t).truth.mean()
    )
    # 方法二: Bagging
    y_bag.append(
        results[results.label==0].sort_values(
            'output_bag', ascending=False
        ).head(t).truth.mean()
    )
    # 方法三：BaggingClassifierPU
    y_skb.append(
        results[results.label==0].sort_values(
            'output_skb', ascending=False
        ).head(t).truth.mean()
    )
    # 方法四：TWO-STEP
    y_stp.append(
        results[results.label==0].sort_values(
            'output_stp', ascending=False
        ).head(t).truth.mean()
    )
    # 方法五：方法一、二、四比较的平均值
    y_all.append(
        results[results.label==0].sort_values(
            'output_all', ascending=False
        ).head(t).truth.mean()
    )

# %%
# 比较PU-Bagging和BaggingClassifierPU 的区别
[y_bag[i] - y_skb[i] for i in range(len(y_bag))]
# Out:
# [0.0,
#  0.0,
#  0.0033333333333332993,
#  0.0,
#  0.0,
#  0.0016666666666667052,
#  0.0014285714285714457,
#  0.0,
#  0.0,
#  0.0010000000000000009,
#  0.0,
#  0.0,
#  0.0,
#  0.002142857142857113,
#  0.002666666666666706,
#  0.0006249999999999867,
#  0.0,
#  0.0,
#  0.001052631578947416,
#  0.0004999999999999449,
#  0.0004761904761904079,
#  0.0013636363636363447,
#  0.00043478260869567187,
#  0.0004166666666666208,
#  0.0,
#  0.00038461538461531664]

# %% [markdown]
# - 四种不同的PU-learning的处理方法展示
# -- Performance graphing

# %%
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 15, 8

plt.plot(
    ts, y_std,
    ts, y_bag,
    ts, y_stp,
    ts, y_all,
    lw=3
)
vals = plt.gca().get_yticks()
plt.yticks(vals, ['%.0f%%' %(v*100) for v in vals])
plt.xlabel('按照最高分数排序选择的未标注数据量')
plt.ylabel('被选中样本肯定为positive的百分比')
plt.legend([
    'Standard classifier',
    'PU Bagging',
    'Two-Step approach',
    'Average score'
])

ylim = plt.gca().get_ylim()
plt.title('三种PU-Learning的方法以及其平均值的表现图')
plt.grid()
plt.show()

# %% [markdown]
# ## 综上从数据集上来看，Bagging表现最好！！！！
